# %%
import pandas as pd
import matplotlib.pyplot as plt
birds = pd.read_csv('birds.csv')
birds.head()
# Out:
#                            Name          ScientificName  \
# 0  Black-bellied whistling-duck  Dendrocygna autumnalis
# 1        Fulvous whistling-duck     Dendrocygna bicolor
# 2                    Snow goose      Anser caerulescens
# 3                  Ross's goose            Anser rossii
# 4   Greater white-fronted goose         Anser albifrons
#
#                 Category         Order    Family        Genus  \
# 0  Ducks/Geese/Waterfowl  Anseriformes  Anatidae  Dendrocygna
# 1  Ducks/Geese/Waterfowl  Anseriformes  Anatidae  Dendrocygna
# 2  Ducks/Geese/Waterfowl  Anseriformes  Anatidae        Anser
# 3  Ducks/Geese/Waterfowl  Anseriformes  Anatidae        Anser
# 4  Ducks/Geese/Waterfowl  Anseriformes  Anatidae        Anser
#
#   ConservationStatus  MinLength  MaxLength  MinBodyMass  MaxBodyMass  \
# 0                 LC       47.0       56.0        652.0       1020.0
# 1                 LC       45.0       53.0        712.0       1050.0
# 2                 LC       64.0       79.0       2050.0       4050.0
# 3                 LC       57.3       64.0       1066.0       1567.0
# 4                 LC       64.0       81.0       1930.0       3310.0
#
#    MinWingspan  MaxWingspan
# 0         76.0         94.0
# 1         85.0         93.0
# 2        135.0        165.0
# 3        113.0        116.0
# 4        130.0        165.0

# %%
birds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 443 entries, 0 to 442
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Name                443 non-null    object
#  1   ScientificName      443 non-null    object
#  2   Category            443 non-null    object
#  3   Order               443 non-null    object
#  4   Family              443 non-null    object
#  5   Genus               443 non-null    object
#  6   ConservationStatus  443 non-null    object
#  7   MinLength           443 non-null    float64
#  8   MaxLength           443 non-null    float64
#  9   MinBodyMass         443 non-null    float64
#  10  MaxBodyMass         443 non-null    float64
#  11  MinWingspan         443 non-null    float64
#  12  MaxWingspan         443 non-null    float64
# dtypes: float64(6), object(7)
# memory usage: 45.1+ KB

# %%
birds.tail()
# Out:
#                 Name      ScientificName          Category          Order  \
# 438    Blue grosbeak  Passerina caerulea  Cardinals/Allies  Passeriformes
# 439   Lazuli bunting    Passerina amoena  Cardinals/Allies  Passeriformes
# 440   Indigo bunting    Passerina cyanea  Cardinals/Allies  Passeriformes
# 441  Painted bunting     Passerina ciris  Cardinals/Allies  Passeriformes
# 442       Dickcissel     Spiza americana  Cardinals/Allies  Passeriformes
#
#            Family      Genus ConservationStatus  MinLength  MaxLength  \
# 438  Cardinalidae  Passerina                 LC       14.0       19.0
# 439  Cardinalidae  Passerina                 LC       13.0       15.0
# 440  Cardinalidae  Passerina                 LC       11.5       15.0
# 441  Cardinalidae  Passerina                 LC       12.0       14.0
# 442  Cardinalidae      Spiza                 LC       14.0       16.0
#
#      MinBodyMass  MaxBodyMass  MinWingspan  MaxWingspan
# 438         26.0         31.5         26.0         29.0
# 439         13.0         18.0         22.0         22.0
# 440         11.2         21.4         18.0         23.0
# 441         13.0         19.0         21.0         23.0
# 442         25.6         38.4         24.8         26.0

# %%
birds.isnull()
# Out:
#       Name  ScientificName  Category  Order  Family  Genus  \
# 0    False           False     False  False   False  False
# 1    False           False     False  False   False  False
# 2    False           False     False  False   False  False
# 3    False           False     False  False   False  False
# 4    False           False     False  False   False  False
# ..     ...             ...       ...    ...     ...    ...
# 438  False           False     False  False   False  False
# 439  False           False     False  False   False  False
# 440  False           False     False  False   False  False
# 441  False           False     False  False   False  False
# 442  False           False     False  False   False  False
#
#      ConservationStatus  MinLength  MaxLength  MinBodyMass  MaxBodyMass  \
# 0                 False      False      False        False        False
# 1                 False      False      False        False        False
# 2                 False      False      False        False        False
# 3                 False      False      False        False        False
# 4                 False      False      False        False        False
# ..                  ...        ...        ...          ...          ...
# 438               False      False      False        False        False
# 439               False      False      False        False        False
# 440               False      False      False        False        False
# 441               False      False      False        False        False
# 442               False      False      False        False        False
#
#      MinWingspan  MaxWingspan
# 0          False        False
# 1          False        False
# 2          False        False
# 3          False        False
# 4          False        False
# ..           ...          ...
# 438        False        False
# 439        False        False
# 440        False        False
# 441        False        False
# 442        False        False
#
# [443 rows x 13 columns]

# %%
example1 = birds.dropna()
example1
# Out:
#                              Name          ScientificName  \
# 0    Black-bellied whistling-duck  Dendrocygna autumnalis
# 1          Fulvous whistling-duck     Dendrocygna bicolor
# 2                      Snow goose      Anser caerulescens
# 3                    Ross's goose            Anser rossii
# 4     Greater white-fronted goose         Anser albifrons
# ..                            ...                     ...
# 438                 Blue grosbeak      Passerina caerulea
# 439                Lazuli bunting        Passerina amoena
# 440                Indigo bunting        Passerina cyanea
# 441               Painted bunting         Passerina ciris
# 442                    Dickcissel         Spiza americana
#
#                   Category          Order        Family        Genus  \
# 0    Ducks/Geese/Waterfowl   Anseriformes      Anatidae  Dendrocygna
# 1    Ducks/Geese/Waterfowl   Anseriformes      Anatidae  Dendrocygna
# 2    Ducks/Geese/Waterfowl   Anseriformes      Anatidae        Anser
# 3    Ducks/Geese/Waterfowl   Anseriformes      Anatidae        Anser
# 4    Ducks/Geese/Waterfowl   Anseriformes      Anatidae        Anser
# ..                     ...            ...           ...          ...
# 438       Cardinals/Allies  Passeriformes  Cardinalidae    Passerina
# 439       Cardinals/Allies  Passeriformes  Cardinalidae    Passerina
# 440       Cardinals/Allies  Passeriformes  Cardinalidae    Passerina
# 441       Cardinals/Allies  Passeriformes  Cardinalidae    Passerina
# 442       Cardinals/Allies  Passeriformes  Cardinalidae        Spiza
#
#     ConservationStatus  MinLength  MaxLength  MinBodyMass  MaxBodyMass  \
# 0                   LC       47.0       56.0        652.0       1020.0
# 1                   LC       45.0       53.0        712.0       1050.0
# 2                   LC       64.0       79.0       2050.0       4050.0
# 3                   LC       57.3       64.0       1066.0       1567.0
# 4                   LC       64.0       81.0       1930.0       3310.0
# ..                 ...        ...        ...          ...          ...
# 438                 LC       14.0       19.0         26.0         31.5
# 439                 LC       13.0       15.0         13.0         18.0
# 440                 LC       11.5       15.0         11.2         21.4
# 441                 LC       12.0       14.0         13.0         19.0
# 442                 LC       14.0       16.0         25.6         38.4
#
#      MinWingspan  MaxWingspan
# 0           76.0         94.0
# 1           85.0         93.0
# 2          135.0        165.0
# 3          113.0        116.0
# 4          130.0        165.0
# ..           ...          ...
# 438         26.0         29.0
# 439         22.0         22.0
# 440         18.0         23.0
# 441         21.0         23.0
# 442         24.8         26.0
#
# [443 rows x 13 columns]

# %%
birds.dropna(axis='columns')
# Out:
#                              Name          ScientificName  \
# 0    Black-bellied whistling-duck  Dendrocygna autumnalis
# 1          Fulvous whistling-duck     Dendrocygna bicolor
# 2                      Snow goose      Anser caerulescens
# 3                    Ross's goose            Anser rossii
# 4     Greater white-fronted goose         Anser albifrons
# ..                            ...                     ...
# 438                 Blue grosbeak      Passerina caerulea
# 439                Lazuli bunting        Passerina amoena
# 440                Indigo bunting        Passerina cyanea
# 441               Painted bunting         Passerina ciris
# 442                    Dickcissel         Spiza americana
#
#                   Category          Order        Family        Genus  \
# 0    Ducks/Geese/Waterfowl   Anseriformes      Anatidae  Dendrocygna
# 1    Ducks/Geese/Waterfowl   Anseriformes      Anatidae  Dendrocygna
# 2    Ducks/Geese/Waterfowl   Anseriformes      Anatidae        Anser
# 3    Ducks/Geese/Waterfowl   Anseriformes      Anatidae        Anser
# 4    Ducks/Geese/Waterfowl   Anseriformes      Anatidae        Anser
# ..                     ...            ...           ...          ...
# 438       Cardinals/Allies  Passeriformes  Cardinalidae    Passerina
# 439       Cardinals/Allies  Passeriformes  Cardinalidae    Passerina
# 440       Cardinals/Allies  Passeriformes  Cardinalidae    Passerina
# 441       Cardinals/Allies  Passeriformes  Cardinalidae    Passerina
# 442       Cardinals/Allies  Passeriformes  Cardinalidae        Spiza
#
#     ConservationStatus  MinLength  MaxLength  MinBodyMass  MaxBodyMass  \
# 0                   LC       47.0       56.0        652.0       1020.0
# 1                   LC       45.0       53.0        712.0       1050.0
# 2                   LC       64.0       79.0       2050.0       4050.0
# 3                   LC       57.3       64.0       1066.0       1567.0
# 4                   LC       64.0       81.0       1930.0       3310.0
# ..                 ...        ...        ...          ...          ...
# 438                 LC       14.0       19.0         26.0         31.5
# 439                 LC       13.0       15.0         13.0         18.0
# 440                 LC       11.5       15.0         11.2         21.4
# 441                 LC       12.0       14.0         13.0         19.0
# 442                 LC       14.0       16.0         25.6         38.4
#
#      MinWingspan  MaxWingspan
# 0           76.0         94.0
# 1           85.0         93.0
# 2          135.0        165.0
# 3          113.0        116.0
# 4          130.0        165.0
# ..           ...          ...
# 438         26.0         29.0
# 439         22.0         22.0
# 440         18.0         23.0
# 441         21.0         23.0
# 442         24.8         26.0
#
# [443 rows x 13 columns]

# %%
birds.dropna(axis='rows', thresh=3)
# Out:
#                              Name          ScientificName  \
# 0    Black-bellied whistling-duck  Dendrocygna autumnalis
# 1          Fulvous whistling-duck     Dendrocygna bicolor
# 2                      Snow goose      Anser caerulescens
# 3                    Ross's goose            Anser rossii
# 4     Greater white-fronted goose         Anser albifrons
# ..                            ...                     ...
# 438                 Blue grosbeak      Passerina caerulea
# 439                Lazuli bunting        Passerina amoena
# 440                Indigo bunting        Passerina cyanea
# 441               Painted bunting         Passerina ciris
# 442                    Dickcissel         Spiza americana
#
#                   Category          Order        Family        Genus  \
# 0    Ducks/Geese/Waterfowl   Anseriformes      Anatidae  Dendrocygna
# 1    Ducks/Geese/Waterfowl   Anseriformes      Anatidae  Dendrocygna
# 2    Ducks/Geese/Waterfowl   Anseriformes      Anatidae        Anser
# 3    Ducks/Geese/Waterfowl   Anseriformes      Anatidae        Anser
# 4    Ducks/Geese/Waterfowl   Anseriformes      Anatidae        Anser
# ..                     ...            ...           ...          ...
# 438       Cardinals/Allies  Passeriformes  Cardinalidae    Passerina
# 439       Cardinals/Allies  Passeriformes  Cardinalidae    Passerina
# 440       Cardinals/Allies  Passeriformes  Cardinalidae    Passerina
# 441       Cardinals/Allies  Passeriformes  Cardinalidae    Passerina
# 442       Cardinals/Allies  Passeriformes  Cardinalidae        Spiza
#
#     ConservationStatus  MinLength  MaxLength  MinBodyMass  MaxBodyMass  \
# 0                   LC       47.0       56.0        652.0       1020.0
# 1                   LC       45.0       53.0        712.0       1050.0
# 2                   LC       64.0       79.0       2050.0       4050.0
# 3                   LC       57.3       64.0       1066.0       1567.0
# 4                   LC       64.0       81.0       1930.0       3310.0
# ..                 ...        ...        ...          ...          ...
# 438                 LC       14.0       19.0         26.0         31.5
# 439                 LC       13.0       15.0         13.0         18.0
# 440                 LC       11.5       15.0         11.2         21.4
# 441                 LC       12.0       14.0         13.0         19.0
# 442                 LC       14.0       16.0         25.6         38.4
#
#      MinWingspan  MaxWingspan
# 0           76.0         94.0
# 1           85.0         93.0
# 2          135.0        165.0
# 3          113.0        116.0
# 4          130.0        165.0
# ..           ...          ...
# 438         26.0         29.0
# 439         22.0         22.0
# 440         18.0         23.0
# 441         21.0         23.0
# 442         24.8         26.0
#
# [443 rows x 13 columns]

# %%
birds.fillna(0)
# Out:
#                              Name          ScientificName  \
# 0    Black-bellied whistling-duck  Dendrocygna autumnalis
# 1          Fulvous whistling-duck     Dendrocygna bicolor
# 2                      Snow goose      Anser caerulescens
# 3                    Ross's goose            Anser rossii
# 4     Greater white-fronted goose         Anser albifrons
# ..                            ...                     ...
# 438                 Blue grosbeak      Passerina caerulea
# 439                Lazuli bunting        Passerina amoena
# 440                Indigo bunting        Passerina cyanea
# 441               Painted bunting         Passerina ciris
# 442                    Dickcissel         Spiza americana
#
#                   Category          Order        Family        Genus  \
# 0    Ducks/Geese/Waterfowl   Anseriformes      Anatidae  Dendrocygna
# 1    Ducks/Geese/Waterfowl   Anseriformes      Anatidae  Dendrocygna
# 2    Ducks/Geese/Waterfowl   Anseriformes      Anatidae        Anser
# 3    Ducks/Geese/Waterfowl   Anseriformes      Anatidae        Anser
# 4    Ducks/Geese/Waterfowl   Anseriformes      Anatidae        Anser
# ..                     ...            ...           ...          ...
# 438       Cardinals/Allies  Passeriformes  Cardinalidae    Passerina
# 439       Cardinals/Allies  Passeriformes  Cardinalidae    Passerina
# 440       Cardinals/Allies  Passeriformes  Cardinalidae    Passerina
# 441       Cardinals/Allies  Passeriformes  Cardinalidae    Passerina
# 442       Cardinals/Allies  Passeriformes  Cardinalidae        Spiza
#
#     ConservationStatus  MinLength  MaxLength  MinBodyMass  MaxBodyMass  \
# 0                   LC       47.0       56.0        652.0       1020.0
# 1                   LC       45.0       53.0        712.0       1050.0
# 2                   LC       64.0       79.0       2050.0       4050.0
# 3                   LC       57.3       64.0       1066.0       1567.0
# 4                   LC       64.0       81.0       1930.0       3310.0
# ..                 ...        ...        ...          ...          ...
# 438                 LC       14.0       19.0         26.0         31.5
# 439                 LC       13.0       15.0         13.0         18.0
# 440                 LC       11.5       15.0         11.2         21.4
# 441                 LC       12.0       14.0         13.0         19.0
# 442                 LC       14.0       16.0         25.6         38.4
#
#      MinWingspan  MaxWingspan
# 0           76.0         94.0
# 1           85.0         93.0
# 2          135.0        165.0
# 3          113.0        116.0
# 4          130.0        165.0
# ..           ...          ...
# 438         26.0         29.0
# 439         22.0         22.0
# 440         18.0         23.0
# 441         21.0         23.0
# 442         24.8         26.0
#
# [443 rows x 13 columns]

# %%
birds.fillna(method='ffill')
# Out:
#                              Name          ScientificName  \
# 0    Black-bellied whistling-duck  Dendrocygna autumnalis
# 1          Fulvous whistling-duck     Dendrocygna bicolor
# 2                      Snow goose      Anser caerulescens
# 3                    Ross's goose            Anser rossii
# 4     Greater white-fronted goose         Anser albifrons
# ..                            ...                     ...
# 438                 Blue grosbeak      Passerina caerulea
# 439                Lazuli bunting        Passerina amoena
# 440                Indigo bunting        Passerina cyanea
# 441               Painted bunting         Passerina ciris
# 442                    Dickcissel         Spiza americana
#
#                   Category          Order        Family        Genus  \
# 0    Ducks/Geese/Waterfowl   Anseriformes      Anatidae  Dendrocygna
# 1    Ducks/Geese/Waterfowl   Anseriformes      Anatidae  Dendrocygna
# 2    Ducks/Geese/Waterfowl   Anseriformes      Anatidae        Anser
# 3    Ducks/Geese/Waterfowl   Anseriformes      Anatidae        Anser
# 4    Ducks/Geese/Waterfowl   Anseriformes      Anatidae        Anser
# ..                     ...            ...           ...          ...
# 438       Cardinals/Allies  Passeriformes  Cardinalidae    Passerina
# 439       Cardinals/Allies  Passeriformes  Cardinalidae    Passerina
# 440       Cardinals/Allies  Passeriformes  Cardinalidae    Passerina
# 441       Cardinals/Allies  Passeriformes  Cardinalidae    Passerina
# 442       Cardinals/Allies  Passeriformes  Cardinalidae        Spiza
#
#     ConservationStatus  MinLength  MaxLength  MinBodyMass  MaxBodyMass  \
# 0                   LC       47.0       56.0        652.0       1020.0
# 1                   LC       45.0       53.0        712.0       1050.0
# 2                   LC       64.0       79.0       2050.0       4050.0
# 3                   LC       57.3       64.0       1066.0       1567.0
# 4                   LC       64.0       81.0       1930.0       3310.0
# ..                 ...        ...        ...          ...          ...
# 438                 LC       14.0       19.0         26.0         31.5
# 439                 LC       13.0       15.0         13.0         18.0
# 440                 LC       11.5       15.0         11.2         21.4
# 441                 LC       12.0       14.0         13.0         19.0
# 442                 LC       14.0       16.0         25.6         38.4
#
#      MinWingspan  MaxWingspan
# 0           76.0         94.0
# 1           85.0         93.0
# 2          135.0        165.0
# 3          113.0        116.0
# 4          130.0        165.0
# ..           ...          ...
# 438         26.0         29.0
# 439         22.0         22.0
# 440         18.0         23.0
# 441         21.0         23.0
# 442         24.8         26.0
#
# [443 rows x 13 columns]

# %%
birds.fillna(method='ffill', axis=1)
# Out:
#                              Name          ScientificName  \
# 0    Black-bellied whistling-duck  Dendrocygna autumnalis
# 1          Fulvous whistling-duck     Dendrocygna bicolor
# 2                      Snow goose      Anser caerulescens
# 3                    Ross's goose            Anser rossii
# 4     Greater white-fronted goose         Anser albifrons
# ..                            ...                     ...
# 438                 Blue grosbeak      Passerina caerulea
# 439                Lazuli bunting        Passerina amoena
# 440                Indigo bunting        Passerina cyanea
# 441               Painted bunting         Passerina ciris
# 442                    Dickcissel         Spiza americana
#
#                   Category          Order        Family        Genus  \
# 0    Ducks/Geese/Waterfowl   Anseriformes      Anatidae  Dendrocygna
# 1    Ducks/Geese/Waterfowl   Anseriformes      Anatidae  Dendrocygna
# 2    Ducks/Geese/Waterfowl   Anseriformes      Anatidae        Anser
# 3    Ducks/Geese/Waterfowl   Anseriformes      Anatidae        Anser
# 4    Ducks/Geese/Waterfowl   Anseriformes      Anatidae        Anser
# ..                     ...            ...           ...          ...
# 438       Cardinals/Allies  Passeriformes  Cardinalidae    Passerina
# 439       Cardinals/Allies  Passeriformes  Cardinalidae    Passerina
# 440       Cardinals/Allies  Passeriformes  Cardinalidae    Passerina
# 441       Cardinals/Allies  Passeriformes  Cardinalidae    Passerina
# 442       Cardinals/Allies  Passeriformes  Cardinalidae        Spiza
#
#     ConservationStatus MinLength MaxLength MinBodyMass MaxBodyMass  \
# 0                   LC      47.0      56.0       652.0      1020.0
# 1                   LC      45.0      53.0       712.0      1050.0
# 2                   LC      64.0      79.0      2050.0      4050.0
# 3                   LC      57.3      64.0      1066.0      1567.0
# 4                   LC      64.0      81.0      1930.0      3310.0
# ..                 ...       ...       ...         ...         ...
# 438                 LC      14.0      19.0        26.0        31.5
# 439                 LC      13.0      15.0        13.0        18.0
# 440                 LC      11.5      15.0        11.2        21.4
# 441                 LC      12.0      14.0        13.0        19.0
# 442                 LC      14.0      16.0        25.6        38.4
#
#     MinWingspan MaxWingspan
# 0          76.0        94.0
# 1          85.0        93.0
# 2         135.0       165.0
# 3         113.0       116.0
# 4         130.0       165.0
# ..          ...         ...
# 438        26.0        29.0
# 439        22.0        22.0
# 440        18.0        23.0
# 441        21.0        23.0
# 442        24.8        26.0
#
# [443 rows x 13 columns]

# %% [markdown]
# Removing duplicate data

# %%
birds.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 438    False
# 439    False
# 440    False
# 441    False
# 442    False
# Length: 443, dtype: bool

# %%
birds.drop_duplicates()
# Out:
#                              Name          ScientificName  \
# 0    Black-bellied whistling-duck  Dendrocygna autumnalis
# 1          Fulvous whistling-duck     Dendrocygna bicolor
# 2                      Snow goose      Anser caerulescens
# 3                    Ross's goose            Anser rossii
# 4     Greater white-fronted goose         Anser albifrons
# ..                            ...                     ...
# 438                 Blue grosbeak      Passerina caerulea
# 439                Lazuli bunting        Passerina amoena
# 440                Indigo bunting        Passerina cyanea
# 441               Painted bunting         Passerina ciris
# 442                    Dickcissel         Spiza americana
#
#                   Category          Order        Family        Genus  \
# 0    Ducks/Geese/Waterfowl   Anseriformes      Anatidae  Dendrocygna
# 1    Ducks/Geese/Waterfowl   Anseriformes      Anatidae  Dendrocygna
# 2    Ducks/Geese/Waterfowl   Anseriformes      Anatidae        Anser
# 3    Ducks/Geese/Waterfowl   Anseriformes      Anatidae        Anser
# 4    Ducks/Geese/Waterfowl   Anseriformes      Anatidae        Anser
# ..                     ...            ...           ...          ...
# 438       Cardinals/Allies  Passeriformes  Cardinalidae    Passerina
# 439       Cardinals/Allies  Passeriformes  Cardinalidae    Passerina
# 440       Cardinals/Allies  Passeriformes  Cardinalidae    Passerina
# 441       Cardinals/Allies  Passeriformes  Cardinalidae    Passerina
# 442       Cardinals/Allies  Passeriformes  Cardinalidae        Spiza
#
#     ConservationStatus  MinLength  MaxLength  MinBodyMass  MaxBodyMass  \
# 0                   LC       47.0       56.0        652.0       1020.0
# 1                   LC       45.0       53.0        712.0       1050.0
# 2                   LC       64.0       79.0       2050.0       4050.0
# 3                   LC       57.3       64.0       1066.0       1567.0
# 4                   LC       64.0       81.0       1930.0       3310.0
# ..                 ...        ...        ...          ...          ...
# 438                 LC       14.0       19.0         26.0         31.5
# 439                 LC       13.0       15.0         13.0         18.0
# 440                 LC       11.5       15.0         11.2         21.4
# 441                 LC       12.0       14.0         13.0         19.0
# 442                 LC       14.0       16.0         25.6         38.4
#
#      MinWingspan  MaxWingspan
# 0           76.0         94.0
# 1           85.0         93.0
# 2          135.0        165.0
# 3          113.0        116.0
# 4          130.0        165.0
# ..           ...          ...
# 438         26.0         29.0
# 439         22.0         22.0
# 440         18.0         23.0
# 441         21.0         23.0
# 442         24.8         26.0
#
# [443 rows x 13 columns]

# %%
birds.drop_duplicates(['Family'])
# Out:
#                              Name             ScientificName  \
# 0    Black-bellied whistling-duck     Dendrocygna autumnalis
# 45              Northern bobwhite        Colinus virginianus
# 46                    Wild turkey        Meleagris gallopavo
# 55              Pied-billed grebe        Podilymbus podiceps
# 61                    Rock pigeon              Columba livia
# 69              Groove-billed ani    Crotophaga sulcirostris
# 72               Common nighthawk           Chordeiles minor
# 76                  Chimney swift          Chaetura pelagica
# 78              Mexican violetear        Colibri thalassinus
# 85                      King rail             Rallus elegans
# 93                 Sandhill crane        Antigone canadensis
# 95             Black-necked stilt       Himantopus mexicanus
# 97           Black-bellied plover       Pluvialis squatarola
# 104              Upland sandpiper       Bartramia longicauda
# 138               Pomarine jaeger     Stercorarius pomarinus
# 141                       Dovekie                  Alle alle
# 145        Black-legged kittiwake           Rissa tridactyla
# 173             Red-throated loon             Gavia stellata
# 177               Northern fulmar         Fulmarus glacialis
# 178                    Wood stork         Mycteria americana
# 179       Magnificent frigatebird        Fregata magnificens
# 180      Double-crested cormorant      Phalacrocorax auritus
# 182        American white pelican  Pelecanus erythrorhynchos
# 184              American bittern      Botaurus lentiginosus
# 195                    White ibis            Eudocimus albus
# 199                 Black vulture           Coragyps atratus
# 201                        Osprey          Pandion haliaetus
# 202             White-tailed kite            Elanus leucurus
# 217                      Barn owl                  Tyto alba
# 218           Eastern screech-owl             Megascops asio
# 229             Belted kingfisher           Megaeryle alcyon
# 230            Lewis's woodpecker           Melanerpes lewis
# 242              Crested caracara          Caracara cheriway
# 248       Ash-throated flycatcher      Myiarchus cinerascens
# 267             Loggerhead shrike        Lanius ludovicianus
# 269              White-eyed vireo              Vireo griseus
# 276                    Canada jay      Perisoreus canadensis
# 282                   Horned lark       Eremophila alpestris
# 283                  Bank swallow            Riparia riparia
# 290        Black-capped chickadee        Poecile atricapilla
# 293         Red-breasted nuthatch           Sitta canadensis
# 296                 Brown creeper          Certhia americana
# 297                     Rock wren       Salpinctes obsoletus
# 304         Blue-gray gnatcatcher        Polioptila caerulea
# 305               American dipper          Cinclus mexicanus
# 306        Golden-crowned kinglet            Regulus satrapa
# 308             Northern wheatear          Oenanthe oenanthe
# 309              Eastern bluebird              Sialia sialis
# 320                  Gray catbird     Dumetella carolinensis
# 325             European starling           Sturnus vulgaris
# 326              Bohemian waxwing        Bombycilla garrulus
# 328                 House sparrow          Passer domesticus
# 330                American pipit           Anthus rubescens
# 332                     Brambling   Fringilla montifringilla
# 345              Lapland longspur       Calcarius lapponicus
# 350           Grasshopper sparrow      Ammodramus savannarum
# 376          Yellow-breasted chat             Icteria virens
# 391                      Ovenbird        Seiurus aurocapilla
# 432                Summer tanager              Piranga rubra
#
#                             Category              Order             Family  \
# 0              Ducks/Geese/Waterfowl       Anseriformes           Anatidae
# 45                   New World quail        Galliformes     Odontophoridae
# 46           Pheasants/Grouse/Allies        Galliformes        Phasianidae
# 55                            Grebes   Podicipediformes      Podicipedidae
# 61                     Pigeons/Doves      Columbiformes         Columbidae
# 69                           Cuckoos       Cuculiformes          Cuculidae
# 72                  Nightjars/Allies   Caprimulgiformes      Caprimulgidae
# 76                            Swifts        Apodiformes           Apodidae
# 78                      Hummingbirds        Apodiformes        Trochilidae
# 85            Rails/Gallinules/Coots         Gruiformes           Rallidae
# 93                            Cranes         Gruiformes            Gruidae
# 95                Stilts and avocets    Charadriiformes   Recurvirostridae
# 97                  Plovers/Lapwings    Charadriiformes       Charadriidae
# 104                Sandpipers/Allies    Charadriiformes       Scolopacidae
# 138                Skuas and jaegers    Charadriiformes     Stercorariidae
# 141              Auks/Murres/Puffins    Charadriiformes            Alcidae
# 145             Gulls/Terns/Skimmers    Charadriiformes            Laridae
# 173                            Loons        Gaviiformes           Gaviidae
# 177          Shearwaters and petrels  Procellariiformes     Procellariidae
# 178                           Storks      Ciconiiformes         Ciconiidae
# 179                     Frigatebirds         Suliformes         Fregatidae
# 180                 Cormorants/Shags         Suliformes  Phalacrocoracidae
# 182                         Pelicans     Pelecaniformes        Pelecanidae
# 184           Herons/Egrets/Bitterns     Pelecaniformes           Ardeidae
# 195                Ibises/Spoonbills     Pelecaniformes  Threskiornithidae
# 199               New World vultures     Cathartiformes        Cathartidae
# 201                           Osprey    Accipitriformes        Pandionidae
# 202                     Hawks/Eagles    Accipitriformes       Accipitridae
# 217                        Barn-owls       Strigiformes          Tytonidae
# 218                             Owls       Strigiformes          Strigidae
# 229                      Kingfishers      Coraciiformes        Alcedinidae
# 230                      Woodpeckers         Piciformes            Picidae
# 242               Falcons /Caracaras       Falconformes         Falconidae
# 248               Tyrant flycatchers      Passeriformes         Tyrannidae
# 267                          Shrikes      Passeriformes           Laniidae
# 269  Vireos/Shrike-babblers/Erpornis      Passeriformes         Vireonidae
# 276               Crows/Jays/Magpies      Passeriformes           Corvidae
# 282                            Larks      Passeriformes          Alaudidae
# 283                         Swallows      Passeriformes       Hirundinidae
# 290          Tits/Chickadees/Titmice      Passeriformes            Paridae
# 293                       Nuthatches      Passeriformes           Sittidae
# 296                     Treecreepers      Passeriformes         Certhiidae
# 297                            Wrens      Passeriformes      Troglodytidae
# 304                     Gnatcatchers      Passeriformes      Polioptilidae
# 305                          Dippers      Passeriformes          Cinclidae
# 306                         Kinglets      Passeriformes          Regulidae
# 308            Old World flycatchers      Passeriformes       Muscicapidae
# 309                  Thrushes/Allies      Passeriformes           Turdidae
# 320           Mockingbirds/Thrashers      Passeriformes            Mimidae
# 325                        Starlings      Passeriformes          Sturnidae
# 326                         Waxwings      Passeriformes      Bombycillidae
# 328               Old World sparrows      Passeriformes         Passeridae
# 330                 Wagtails/Pitpits      Passeriformes       Motacillidae
# 332         Finches/Euphonias/Allies      Passeriformes       Fringillidae
# 345          Longspurs/Snow buntings      Passeriformes        Calcariidae
# 350               New World sparrows      Passeriformes      Passerellidae
# 376             Yellow-breasted chat      Passeriformes          Icteridae
# 391               New World warblers      Passeriformes          Parulidae
# 432                 Cardinals/Allies      Passeriformes       Cardinalidae
#
#              Genus ConservationStatus  MinLength  MaxLength  MinBodyMass  \
# 0      Dendrocygna                 LC       47.0       56.0        652.0
# 45         Colinus                 NT       24.0       28.0        129.0
# 46       Meleagris                 LC      110.0      115.0       2500.0
# 55      Podilymbus                 LC       31.0       38.0        253.0
# 61         Columba                 LC       29.0       37.0        238.0
# 69      Crotophaga                 LC       34.0       34.0         70.0
# 72      Chordeiles                 LC       22.0       25.0         55.0
# 76        Chaetura                 VU       12.0       15.0         17.0
# 78         Colibri                 LC        9.7       12.0          4.8
# 85          Rallus                 NT       15.5       19.0        290.0
# 93        Antigone                 LC       80.0      136.0       4020.0
# 95      Himantopus                 LC       35.0       39.0        150.0
# 97       Pluvialis                 LC       27.0       30.0        190.0
# 104      Bartramia                 LC       30.0       30.0        170.0
# 138   Stercorarius                 LC       46.0       67.0        540.0
# 141           Alle                 LC       19.0       21.0        134.0
# 145          Rissa                 VU       37.0       41.0        305.0
# 173          Gavia                 LC       53.0       69.0       1000.0
# 177       Fulmarus                 LC       46.0       46.0        450.0
# 178       Mycteria                 LC       83.0      115.0       2000.0
# 179        Fregata                 LC       89.0      114.0       1100.0
# 180  Phalacrocorax                 LC       70.0       90.0       1200.0
# 182      Pelecanus                 LC      130.0      180.0       3500.0
# 184        Botarus                 LC       58.0       85.0        370.0
# 195      Eudocimus                 LC       53.0       70.0        592.7
# 199       Coragyps                 LC       56.0       74.0       1600.0
# 201        Pandion                 LC       50.0       66.0        900.0
# 202         Elanus                 LC       35.0       43.0        250.0
# 217           Tyto                 LC       33.0       39.0        224.0
# 218      Megascops                 LC       16.0       25.0        121.0
# 229     Megaceryle                 LC       28.0       35.0        113.0
# 230     Melanerpes                 LC       26.0       28.0         88.0
# 242       Caracara                 LC       49.0       63.0        701.0
# 248      Myiarchus                 LC       19.0       22.0         20.0
# 267         Lanius                 NT       20.0       23.0         35.0
# 269          Vireo                 LC       11.0       13.0         10.0
# 276     Perisoreus                 LC       25.0       33.0         65.0
# 282     Eremophila                 LC       16.0       20.0         28.0
# 283        Riparia                 LC       12.0       14.0         10.2
# 290        Poecile                 LC       12.0       15.0          9.0
# 293          Sitta                 LC       11.0       11.0          9.9
# 296        Certhia                 LC       12.0       14.0          5.0
# 297     Salpinctes                 LC       12.5       15.0         15.0
# 304     Polioptila                 LC       10.0       13.0          5.0
# 305        Cinclus                 LC       16.5       16.5         46.0
# 306        Regulus                 LC        8.0       11.0          4.0
# 308       Oenanthe                 LC       14.5       16.0         17.0
# 309         Sialia                 LC       16.0       21.0         27.0
# 320      Dumetella                 LC       20.5       24.0         23.2
# 325        Sturnus                 LC       19.0       23.0         58.0
# 326     Bombycilla                 LC       19.0       23.0         55.0
# 328         Passer                 LC       14.0       18.0         24.0
# 330         Anthus                 LC       16.0       16.0         22.0
# 332      Fringilla                 LC       16.0       16.0         23.0
# 345      Calcarius                 LC       15.0       16.0         22.3
# 350     Ammodramus                 LC       10.0       14.0         13.8
# 376        Icteria                 LC       17.0       19.1         20.2
# 391        Seiurus                 LC       11.0       16.0         14.0
# 432        Piranga                 LC       17.0       17.0         29.0
#
#      MaxBodyMass  MinWingspan  MaxWingspan
# 0         1020.0         76.0         94.0
# 45         173.0         33.0         38.0
# 46       10800.0        125.0        144.0
# 55         568.0         45.0         62.0
# 61         380.0         62.0         72.0
# 69          90.0         41.0         46.0
# 72          98.0         51.0         61.0
# 76          30.0         27.0         30.0
# 78           5.6         12.0         12.0
# 85         290.0         48.0         48.0
# 93        4570.0        200.0        200.0
# 95         176.0         71.5         75.5
# 97         280.0         71.0         83.0
# 104        170.0         66.0         66.0
# 138        920.0        110.0        138.0
# 141        204.0         34.0         38.0
# 145        525.0         91.0        105.0
# 173       2700.0         91.0        120.0
# 177       1000.0        102.0        112.0
# 178       3300.0        140.0        180.0
# 179       1590.0        217.0        244.0
# 180       2500.0        114.0        123.0
# 182      13600.0        240.0        300.0
# 184       1072.0         92.0        115.0
# 195       1261.0         90.0        105.0
# 199       3000.0        133.0        167.0
# 201       2100.0        127.0        180.0
# 202        380.0         88.0        102.0
# 217        710.0         80.0         95.0
# 218        244.0         46.0         61.0
# 229        178.0         48.0         58.0
# 230        138.0         49.0         52.0
# 242       1387.0        118.0        132.0
# 248         37.0         30.0         32.0
# 267         50.0         28.0         32.0
# 269         14.0         17.0         17.0
# 276         70.0         45.0         45.0
# 282         48.0         30.0         34.0
# 283         18.8         25.0         33.0
# 290         14.0         16.0         21.0
# 293          9.9         22.0         22.0
# 296         10.0         17.0         20.0
# 297         18.0         22.0         24.0
# 304          7.0         16.0         16.0
# 305         46.0         23.0         23.0
# 306          7.8         14.0         18.0
# 308         30.0         26.0         32.0
# 309         34.0         25.0         32.0
# 320         56.5         22.0         30.0
# 325        101.0         31.0         44.0
# 326         55.0         32.0         35.5
# 328         29.5         19.0         25.0
# 330         22.0         24.0         24.0
# 332         29.0         25.0         26.0
# 345         33.1         22.0         29.0
# 350         28.4         17.5         17.5
# 376         33.8         23.0         27.0
# 391         28.8         19.0         26.0
# 432         29.0         28.0         30.0

# %%
birds.shape
# Out:
# (443, 13)

# %%
birds.columns
# Out:
# Index(['Name', 'ScientificName', 'Category', 'Order', 'Family', 'Genus',
#        'ConservationStatus', 'MinLength', 'MaxLength', 'MinBodyMass',
#        'MaxBodyMass', 'MinWingspan', 'MaxWingspan'],
#       dtype='object')

# %%
birds.info
# Out:
# <bound method DataFrame.info of                              Name          ScientificName  \
# 0    Black-bellied whistling-duck  Dendrocygna autumnalis
# 1          Fulvous whistling-duck     Dendrocygna bicolor
# 2                      Snow goose      Anser caerulescens
# 3                    Ross's goose            Anser rossii
# 4     Greater white-fronted goose         Anser albifrons
# ..                            ...                     ...
# 438                 Blue grosbeak      Passerina caerulea
# 439                Lazuli bunting        Passerina amoena
# 440                Indigo bunting        Passerina cyanea
# 441               Painted bunting         Passerina ciris
# 442                    Dickcissel         Spiza americana
#
#                   Category          Order        Family        Genus  \
# 0    Ducks/Geese/Waterfowl   Anseriformes      Anatidae  Dendrocygna
# 1    Ducks/Geese/Waterfowl   Anseriformes      Anatidae  Dendrocygna
# 2    Ducks/Geese/Waterfowl   Anseriformes      Anatidae        Anser
# 3    Ducks/Geese/Waterfowl   Anseriformes      Anatidae        Anser
# 4    Ducks/Geese/Waterfowl   Anseriformes      Anatidae        Anser
# ..                     ...            ...           ...          ...
# 438       Cardinals/Allies  Passeriformes  Cardinalidae    Passerina
# 439       Cardinals/Allies  Passeriformes  Cardinalidae    Passerina
# 440       Cardinals/Allies  Passeriformes  Cardinalidae    Passerina
# 441       Cardinals/Allies  Passeriformes  Cardinalidae    Passerina
# 442       Cardinals/Allies  Passeriformes  Cardinalidae        Spiza
#
#     ConservationStatus  MinLength  MaxLength  MinBodyMass  MaxBodyMass  \
# 0                   LC       47.0       56.0        652.0       1020.0
# 1                   LC       45.0       53.0        712.0       1050.0
# 2                   LC       64.0       79.0       2050.0       4050.0
# 3                   LC       57.3       64.0       1066.0       1567.0
# 4                   LC       64.0       81.0       1930.0       3310.0
# ..                 ...        ...        ...          ...          ...
# 438                 LC       14.0       19.0         26.0         31.5
# 439                 LC       13.0       15.0         13.0         18.0
# 440                 LC       11.5       15.0         11.2         21.4
# 441                 LC       12.0       14.0         13.0         19.0
# 442                 LC       14.0       16.0         25.6         38.4
#
#      MinWingspan  MaxWingspan
# 0           76.0         94.0
# 1           85.0         93.0
# 2          135.0        165.0
# 3          113.0        116.0
# 4          130.0        165.0
# ..           ...          ...
# 438         26.0         29.0
# 439         22.0         22.0
# 440         18.0         23.0
# 441         21.0         23.0
# 442         24.8         26.0
#
# [443 rows x 13 columns]>

# %%
birds.describe
# Out:
# <bound method NDFrame.describe of                              Name          ScientificName  \
# 0    Black-bellied whistling-duck  Dendrocygna autumnalis
# 1          Fulvous whistling-duck     Dendrocygna bicolor
# 2                      Snow goose      Anser caerulescens
# 3                    Ross's goose            Anser rossii
# 4     Greater white-fronted goose         Anser albifrons
# ..                            ...                     ...
# 438                 Blue grosbeak      Passerina caerulea
# 439                Lazuli bunting        Passerina amoena
# 440                Indigo bunting        Passerina cyanea
# 441               Painted bunting         Passerina ciris
# 442                    Dickcissel         Spiza americana
#
#                   Category          Order        Family        Genus  \
# 0    Ducks/Geese/Waterfowl   Anseriformes      Anatidae  Dendrocygna
# 1    Ducks/Geese/Waterfowl   Anseriformes      Anatidae  Dendrocygna
# 2    Ducks/Geese/Waterfowl   Anseriformes      Anatidae        Anser
# 3    Ducks/Geese/Waterfowl   Anseriformes      Anatidae        Anser
# 4    Ducks/Geese/Waterfowl   Anseriformes      Anatidae        Anser
# ..                     ...            ...           ...          ...
# 438       Cardinals/Allies  Passeriformes  Cardinalidae    Passerina
# 439       Cardinals/Allies  Passeriformes  Cardinalidae    Passerina
# 440       Cardinals/Allies  Passeriformes  Cardinalidae    Passerina
# 441       Cardinals/Allies  Passeriformes  Cardinalidae    Passerina
# 442       Cardinals/Allies  Passeriformes  Cardinalidae        Spiza
#
#     ConservationStatus  MinLength  MaxLength  MinBodyMass  MaxBodyMass  \
# 0                   LC       47.0       56.0        652.0       1020.0
# 1                   LC       45.0       53.0        712.0       1050.0
# 2                   LC       64.0       79.0       2050.0       4050.0
# 3                   LC       57.3       64.0       1066.0       1567.0
# 4                   LC       64.0       81.0       1930.0       3310.0
# ..                 ...        ...        ...          ...          ...
# 438                 LC       14.0       19.0         26.0         31.5
# 439                 LC       13.0       15.0         13.0         18.0
# 440                 LC       11.5       15.0         11.2         21.4
# 441                 LC       12.0       14.0         13.0         19.0
# 442                 LC       14.0       16.0         25.6         38.4
#
#      MinWingspan  MaxWingspan
# 0           76.0         94.0
# 1           85.0         93.0
# 2          135.0        165.0
# 3          113.0        116.0
# 4          130.0        165.0
# ..           ...          ...
# 438         26.0         29.0
# 439         22.0         22.0
# 440         18.0         23.0
# 441         21.0         23.0
# 442         24.8         26.0
#
# [443 rows x 13 columns]>

# %%
birds.head()
# Out:
#                            Name          ScientificName  \
# 0  Black-bellied whistling-duck  Dendrocygna autumnalis
# 1        Fulvous whistling-duck     Dendrocygna bicolor
# 2                    Snow goose      Anser caerulescens
# 3                  Ross's goose            Anser rossii
# 4   Greater white-fronted goose         Anser albifrons
#
#                 Category         Order    Family        Genus  \
# 0  Ducks/Geese/Waterfowl  Anseriformes  Anatidae  Dendrocygna
# 1  Ducks/Geese/Waterfowl  Anseriformes  Anatidae  Dendrocygna
# 2  Ducks/Geese/Waterfowl  Anseriformes  Anatidae        Anser
# 3  Ducks/Geese/Waterfowl  Anseriformes  Anatidae        Anser
# 4  Ducks/Geese/Waterfowl  Anseriformes  Anatidae        Anser
#
#   ConservationStatus  MinLength  MaxLength  MinBodyMass  MaxBodyMass  \
# 0                 LC       47.0       56.0        652.0       1020.0
# 1                 LC       45.0       53.0        712.0       1050.0
# 2                 LC       64.0       79.0       2050.0       4050.0
# 3                 LC       57.3       64.0       1066.0       1567.0
# 4                 LC       64.0       81.0       1930.0       3310.0
#
#    MinWingspan  MaxWingspan
# 0         76.0         94.0
# 1         85.0         93.0
# 2        135.0        165.0
# 3        113.0        116.0
# 4        130.0        165.0

# %%
birds.head(10)
# Out:
#                            Name          ScientificName  \
# 0  Black-bellied whistling-duck  Dendrocygna autumnalis
# 1        Fulvous whistling-duck     Dendrocygna bicolor
# 2                    Snow goose      Anser caerulescens
# 3                  Ross's goose            Anser rossii
# 4   Greater white-fronted goose         Anser albifrons
# 5                         Brant         Branta bernicla
# 6                Cackling goose       Branta hutchinsii
# 7                  Canada goose       Branta canadensis
# 8                     Mute swan             Cygnus olor
# 9                Trumpeter swan       Cygnus buccinator
#
#                 Category         Order    Family        Genus  \
# 0  Ducks/Geese/Waterfowl  Anseriformes  Anatidae  Dendrocygna
# 1  Ducks/Geese/Waterfowl  Anseriformes  Anatidae  Dendrocygna
# 2  Ducks/Geese/Waterfowl  Anseriformes  Anatidae        Anser
# 3  Ducks/Geese/Waterfowl  Anseriformes  Anatidae        Anser
# 4  Ducks/Geese/Waterfowl  Anseriformes  Anatidae        Anser
# 5  Ducks/Geese/Waterfowl  Anseriformes  Anatidae       Branta
# 6  Ducks/Geese/Waterfowl  Anseriformes  Anatidae       Branta
# 7  Ducks/Geese/Waterfowl  Anseriformes  Anatidae       Branta
# 8  Ducks/Geese/Waterfowl  Anseriformes  Anatidae       Cygnus
# 9  Ducks/Geese/Waterfowl  Anseriformes  Anatidae       Cygnus
#
#   ConservationStatus  MinLength  MaxLength  MinBodyMass  MaxBodyMass  \
# 0                 LC       47.0       56.0        652.0       1020.0
# 1                 LC       45.0       53.0        712.0       1050.0
# 2                 LC       64.0       79.0       2050.0       4050.0
# 3                 LC       57.3       64.0       1066.0       1567.0
# 4                 LC       64.0       81.0       1930.0       3310.0
# 5                 LC       55.0       66.0        880.0       2200.0
# 6                 LC       63.0       65.0       1398.0       2380.0
# 7                 LC       75.0      110.0       2600.0       6500.0
# 8                 LC      125.0      170.0       9200.0      14300.0
# 9                 LC      138.0      180.0       7000.0      13600.0
#
#    MinWingspan  MaxWingspan
# 0         76.0         94.0
# 1         85.0         93.0
# 2        135.0        165.0
# 3        113.0        116.0
# 4        130.0        165.0
# 5        206.0        121.0
# 6        108.0        111.0
# 7        127.0        185.0
# 8        200.0        240.0
# 9        185.0        250.0

# %%
birds.tail()
# Out:
#                 Name      ScientificName          Category          Order  \
# 438    Blue grosbeak  Passerina caerulea  Cardinals/Allies  Passeriformes
# 439   Lazuli bunting    Passerina amoena  Cardinals/Allies  Passeriformes
# 440   Indigo bunting    Passerina cyanea  Cardinals/Allies  Passeriformes
# 441  Painted bunting     Passerina ciris  Cardinals/Allies  Passeriformes
# 442       Dickcissel     Spiza americana  Cardinals/Allies  Passeriformes
#
#            Family      Genus ConservationStatus  MinLength  MaxLength  \
# 438  Cardinalidae  Passerina                 LC       14.0       19.0
# 439  Cardinalidae  Passerina                 LC       13.0       15.0
# 440  Cardinalidae  Passerina                 LC       11.5       15.0
# 441  Cardinalidae  Passerina                 LC       12.0       14.0
# 442  Cardinalidae      Spiza                 LC       14.0       16.0
#
#      MinBodyMass  MaxBodyMass  MinWingspan  MaxWingspan
# 438         26.0         31.5         26.0         29.0
# 439         13.0         18.0         22.0         22.0
# 440         11.2         21.4         18.0         23.0
# 441         13.0         19.0         21.0         23.0
# 442         25.6         38.4         24.8         26.0

# %%
birds.tail(10)
# Out:
#                        Name             ScientificName          Category  \
# 433         Scarlet tanager           Piranga olivacea  Cardinals/Allies
# 434         Western tanager        Piranga ludoviciana  Cardinals/Allies
# 435       Northern cardinal      Cardinalis cardinalis  Cardinals/Allies
# 436  Rose-breasted grosbeak    Pheucticus ludovicianus  Cardinals/Allies
# 437   Black-headed grosbeak  Pheucticus melanocephalus  Cardinals/Allies
# 438           Blue grosbeak         Passerina caerulea  Cardinals/Allies
# 439          Lazuli bunting           Passerina amoena  Cardinals/Allies
# 440          Indigo bunting           Passerina cyanea  Cardinals/Allies
# 441         Painted bunting            Passerina ciris  Cardinals/Allies
# 442              Dickcissel            Spiza americana  Cardinals/Allies
#
#              Order        Family       Genus ConservationStatus  MinLength  \
# 433  Passeriformes  Cardinalidae     Piranga                 LC       16.0
# 434  Passeriformes  Cardinalidae     Piranga                 LC       16.0
# 435  Passeriformes  Cardinalidae  Cardinalis                 LC       21.0
# 436  Passeriformes  Cardinalidae  Pheucticus                 LC       18.0
# 437  Passeriformes  Cardinalidae  Pheucticus                 LC       18.0
# 438  Passeriformes  Cardinalidae   Passerina                 LC       14.0
# 439  Passeriformes  Cardinalidae   Passerina                 LC       13.0
# 440  Passeriformes  Cardinalidae   Passerina                 LC       11.5
# 441  Passeriformes  Cardinalidae   Passerina                 LC       12.0
# 442  Passeriformes  Cardinalidae       Spiza                 LC       14.0
#
#      MaxLength  MinBodyMass  MaxBodyMass  MinWingspan  MaxWingspan
# 433       19.0         23.5         38.0         25.0         30.0
# 434       19.0         24.0         36.0         29.0         29.0
# 435       23.5         33.6         65.0         25.0         31.0
# 436       22.0         35.0         65.0         29.0         33.0
# 437       19.0         34.0         49.0         32.0         32.0
# 438       19.0         26.0         31.5         26.0         29.0
# 439       15.0         13.0         18.0         22.0         22.0
# 440       15.0         11.2         21.4         18.0         23.0
# 441       14.0         13.0         19.0         21.0         23.0
# 442       16.0         25.6         38.4         24.8         26.0

# %% [markdown]
# Missing Data

# %%
birds.isnull()
# Out:
#       Name  ScientificName  Category  Order  Family  Genus  \
# 0    False           False     False  False   False  False
# 1    False           False     False  False   False  False
# 2    False           False     False  False   False  False
# 3    False           False     False  False   False  False
# 4    False           False     False  False   False  False
# ..     ...             ...       ...    ...     ...    ...
# 438  False           False     False  False   False  False
# 439  False           False     False  False   False  False
# 440  False           False     False  False   False  False
# 441  False           False     False  False   False  False
# 442  False           False     False  False   False  False
#
#      ConservationStatus  MinLength  MaxLength  MinBodyMass  MaxBodyMass  \
# 0                 False      False      False        False        False
# 1                 False      False      False        False        False
# 2                 False      False      False        False        False
# 3                 False      False      False        False        False
# 4                 False      False      False        False        False
# ..                  ...        ...        ...          ...          ...
# 438               False      False      False        False        False
# 439               False      False      False        False        False
# 440               False      False      False        False        False
# 441               False      False      False        False        False
# 442               False      False      False        False        False
#
#      MinWingspan  MaxWingspan
# 0          False        False
# 1          False        False
# 2          False        False
# 3          False        False
# 4          False        False
# ..           ...          ...
# 438        False        False
# 439        False        False
# 440        False        False
# 441        False        False
# 442        False        False
#
# [443 rows x 13 columns]

# %%
birds.notnull()
# Out:
#      Name  ScientificName  Category  Order  Family  Genus  ConservationStatus  \
# 0    True            True      True   True    True   True                True
# 1    True            True      True   True    True   True                True
# 2    True            True      True   True    True   True                True
# 3    True            True      True   True    True   True                True
# 4    True            True      True   True    True   True                True
# ..    ...             ...       ...    ...     ...    ...                 ...
# 438  True            True      True   True    True   True                True
# 439  True            True      True   True    True   True                True
# 440  True            True      True   True    True   True                True
# 441  True            True      True   True    True   True                True
# 442  True            True      True   True    True   True                True
#
#      MinLength  MaxLength  MinBodyMass  MaxBodyMass  MinWingspan  MaxWingspan
# 0         True       True         True         True         True         True
# 1         True       True         True         True         True         True
# 2         True       True         True         True         True         True
# 3         True       True         True         True         True         True
# 4         True       True         True         True         True         True
# ..         ...        ...          ...          ...          ...          ...
# 438       True       True         True         True         True         True
# 439       True       True         True         True         True         True
# 440       True       True         True         True         True         True
# 441       True       True         True         True         True         True
# 442       True       True         True         True         True         True
#
# [443 rows x 13 columns]

# %%
birds.dropna()
# Out:
#                              Name          ScientificName  \
# 0    Black-bellied whistling-duck  Dendrocygna autumnalis
# 1          Fulvous whistling-duck     Dendrocygna bicolor
# 2                      Snow goose      Anser caerulescens
# 3                    Ross's goose            Anser rossii
# 4     Greater white-fronted goose         Anser albifrons
# ..                            ...                     ...
# 438                 Blue grosbeak      Passerina caerulea
# 439                Lazuli bunting        Passerina amoena
# 440                Indigo bunting        Passerina cyanea
# 441               Painted bunting         Passerina ciris
# 442                    Dickcissel         Spiza americana
#
#                   Category          Order        Family        Genus  \
# 0    Ducks/Geese/Waterfowl   Anseriformes      Anatidae  Dendrocygna
# 1    Ducks/Geese/Waterfowl   Anseriformes      Anatidae  Dendrocygna
# 2    Ducks/Geese/Waterfowl   Anseriformes      Anatidae        Anser
# 3    Ducks/Geese/Waterfowl   Anseriformes      Anatidae        Anser
# 4    Ducks/Geese/Waterfowl   Anseriformes      Anatidae        Anser
# ..                     ...            ...           ...          ...
# 438       Cardinals/Allies  Passeriformes  Cardinalidae    Passerina
# 439       Cardinals/Allies  Passeriformes  Cardinalidae    Passerina
# 440       Cardinals/Allies  Passeriformes  Cardinalidae    Passerina
# 441       Cardinals/Allies  Passeriformes  Cardinalidae    Passerina
# 442       Cardinals/Allies  Passeriformes  Cardinalidae        Spiza
#
#     ConservationStatus  MinLength  MaxLength  MinBodyMass  MaxBodyMass  \
# 0                   LC       47.0       56.0        652.0       1020.0
# 1                   LC       45.0       53.0        712.0       1050.0
# 2                   LC       64.0       79.0       2050.0       4050.0
# 3                   LC       57.3       64.0       1066.0       1567.0
# 4                   LC       64.0       81.0       1930.0       3310.0
# ..                 ...        ...        ...          ...          ...
# 438                 LC       14.0       19.0         26.0         31.5
# 439                 LC       13.0       15.0         13.0         18.0
# 440                 LC       11.5       15.0         11.2         21.4
# 441                 LC       12.0       14.0         13.0         19.0
# 442                 LC       14.0       16.0         25.6         38.4
#
#      MinWingspan  MaxWingspan
# 0           76.0         94.0
# 1           85.0         93.0
# 2          135.0        165.0
# 3          113.0        116.0
# 4          130.0        165.0
# ..           ...          ...
# 438         26.0         29.0
# 439         22.0         22.0
# 440         18.0         23.0
# 441         21.0         23.0
# 442         24.8         26.0
#
# [443 rows x 13 columns]

# %%
birds.fillna(2)
# Out:
#                              Name          ScientificName  \
# 0    Black-bellied whistling-duck  Dendrocygna autumnalis
# 1          Fulvous whistling-duck     Dendrocygna bicolor
# 2                      Snow goose      Anser caerulescens
# 3                    Ross's goose            Anser rossii
# 4     Greater white-fronted goose         Anser albifrons
# ..                            ...                     ...
# 438                 Blue grosbeak      Passerina caerulea
# 439                Lazuli bunting        Passerina amoena
# 440                Indigo bunting        Passerina cyanea
# 441               Painted bunting         Passerina ciris
# 442                    Dickcissel         Spiza americana
#
#                   Category          Order        Family        Genus  \
# 0    Ducks/Geese/Waterfowl   Anseriformes      Anatidae  Dendrocygna
# 1    Ducks/Geese/Waterfowl   Anseriformes      Anatidae  Dendrocygna
# 2    Ducks/Geese/Waterfowl   Anseriformes      Anatidae        Anser
# 3    Ducks/Geese/Waterfowl   Anseriformes      Anatidae        Anser
# 4    Ducks/Geese/Waterfowl   Anseriformes      Anatidae        Anser
# ..                     ...            ...           ...          ...
# 438       Cardinals/Allies  Passeriformes  Cardinalidae    Passerina
# 439       Cardinals/Allies  Passeriformes  Cardinalidae    Passerina
# 440       Cardinals/Allies  Passeriformes  Cardinalidae    Passerina
# 441       Cardinals/Allies  Passeriformes  Cardinalidae    Passerina
# 442       Cardinals/Allies  Passeriformes  Cardinalidae        Spiza
#
#     ConservationStatus  MinLength  MaxLength  MinBodyMass  MaxBodyMass  \
# 0                   LC       47.0       56.0        652.0       1020.0
# 1                   LC       45.0       53.0        712.0       1050.0
# 2                   LC       64.0       79.0       2050.0       4050.0
# 3                   LC       57.3       64.0       1066.0       1567.0
# 4                   LC       64.0       81.0       1930.0       3310.0
# ..                 ...        ...        ...          ...          ...
# 438                 LC       14.0       19.0         26.0         31.5
# 439                 LC       13.0       15.0         13.0         18.0
# 440                 LC       11.5       15.0         11.2         21.4
# 441                 LC       12.0       14.0         13.0         19.0
# 442                 LC       14.0       16.0         25.6         38.4
#
#      MinWingspan  MaxWingspan
# 0           76.0         94.0
# 1           85.0         93.0
# 2          135.0        165.0
# 3          113.0        116.0
# 4          130.0        165.0
# ..           ...          ...
# 438         26.0         29.0
# 439         22.0         22.0
# 440         18.0         23.0
# 441         21.0         23.0
# 442         24.8         26.0
#
# [443 rows x 13 columns]

# %%
birds.isnull().sum()
# Out:
# Name                  0
# ScientificName        0
# Category              0
# Order                 0
# Family                0
# Genus                 0
# ConservationStatus    0
# MinLength             0
# MaxLength             0
# MinBodyMass           0
# MaxBodyMass           0
# MinWingspan           0
# MaxWingspan           0
# dtype: int64

# %%
birds.notnull().sum()
# Out:
# Name                  443
# ScientificName        443
# Category              443
# Order                 443
# Family                443
# Genus                 443
# ConservationStatus    443
# MinLength             443
# MaxLength             443
# MinBodyMass           443
# MaxBodyMass           443
# MinWingspan           443
# MaxWingspan           443
# dtype: int64

# %% [markdown]
# Dealing with missing data

# %%
# Dropping null values
example3 = birds.dropna()
example3
# Out:
#                              Name          ScientificName  \
# 0    Black-bellied whistling-duck  Dendrocygna autumnalis
# 1          Fulvous whistling-duck     Dendrocygna bicolor
# 2                      Snow goose      Anser caerulescens
# 3                    Ross's goose            Anser rossii
# 4     Greater white-fronted goose         Anser albifrons
# ..                            ...                     ...
# 438                 Blue grosbeak      Passerina caerulea
# 439                Lazuli bunting        Passerina amoena
# 440                Indigo bunting        Passerina cyanea
# 441               Painted bunting         Passerina ciris
# 442                    Dickcissel         Spiza americana
#
#                   Category          Order        Family        Genus  \
# 0    Ducks/Geese/Waterfowl   Anseriformes      Anatidae  Dendrocygna
# 1    Ducks/Geese/Waterfowl   Anseriformes      Anatidae  Dendrocygna
# 2    Ducks/Geese/Waterfowl   Anseriformes      Anatidae        Anser
# 3    Ducks/Geese/Waterfowl   Anseriformes      Anatidae        Anser
# 4    Ducks/Geese/Waterfowl   Anseriformes      Anatidae        Anser
# ..                     ...            ...           ...          ...
# 438       Cardinals/Allies  Passeriformes  Cardinalidae    Passerina
# 439       Cardinals/Allies  Passeriformes  Cardinalidae    Passerina
# 440       Cardinals/Allies  Passeriformes  Cardinalidae    Passerina
# 441       Cardinals/Allies  Passeriformes  Cardinalidae    Passerina
# 442       Cardinals/Allies  Passeriformes  Cardinalidae        Spiza
#
#     ConservationStatus  MinLength  MaxLength  MinBodyMass  MaxBodyMass  \
# 0                   LC       47.0       56.0        652.0       1020.0
# 1                   LC       45.0       53.0        712.0       1050.0
# 2                   LC       64.0       79.0       2050.0       4050.0
# 3                   LC       57.3       64.0       1066.0       1567.0
# 4                   LC       64.0       81.0       1930.0       3310.0
# ..                 ...        ...        ...          ...          ...
# 438                 LC       14.0       19.0         26.0         31.5
# 439                 LC       13.0       15.0         13.0         18.0
# 440                 LC       11.5       15.0         11.2         21.4
# 441                 LC       12.0       14.0         13.0         19.0
# 442                 LC       14.0       16.0         25.6         38.4
#
#      MinWingspan  MaxWingspan
# 0           76.0         94.0
# 1           85.0         93.0
# 2          135.0        165.0
# 3          113.0        116.0
# 4          130.0        165.0
# ..           ...          ...
# 438         26.0         29.0
# 439         22.0         22.0
# 440         18.0         23.0
# 441         21.0         23.0
# 442         24.8         26.0
#
# [443 rows x 13 columns]

# %%
birds.dropna(axis='columns')
# Out:
#                              Name          ScientificName  \
# 0    Black-bellied whistling-duck  Dendrocygna autumnalis
# 1          Fulvous whistling-duck     Dendrocygna bicolor
# 2                      Snow goose      Anser caerulescens
# 3                    Ross's goose            Anser rossii
# 4     Greater white-fronted goose         Anser albifrons
# ..                            ...                     ...
# 438                 Blue grosbeak      Passerina caerulea
# 439                Lazuli bunting        Passerina amoena
# 440                Indigo bunting        Passerina cyanea
# 441               Painted bunting         Passerina ciris
# 442                    Dickcissel         Spiza americana
#
#                   Category          Order        Family        Genus  \
# 0    Ducks/Geese/Waterfowl   Anseriformes      Anatidae  Dendrocygna
# 1    Ducks/Geese/Waterfowl   Anseriformes      Anatidae  Dendrocygna
# 2    Ducks/Geese/Waterfowl   Anseriformes      Anatidae        Anser
# 3    Ducks/Geese/Waterfowl   Anseriformes      Anatidae        Anser
# 4    Ducks/Geese/Waterfowl   Anseriformes      Anatidae        Anser
# ..                     ...            ...           ...          ...
# 438       Cardinals/Allies  Passeriformes  Cardinalidae    Passerina
# 439       Cardinals/Allies  Passeriformes  Cardinalidae    Passerina
# 440       Cardinals/Allies  Passeriformes  Cardinalidae    Passerina
# 441       Cardinals/Allies  Passeriformes  Cardinalidae    Passerina
# 442       Cardinals/Allies  Passeriformes  Cardinalidae        Spiza
#
#     ConservationStatus  MinLength  MaxLength  MinBodyMass  MaxBodyMass  \
# 0                   LC       47.0       56.0        652.0       1020.0
# 1                   LC       45.0       53.0        712.0       1050.0
# 2                   LC       64.0       79.0       2050.0       4050.0
# 3                   LC       57.3       64.0       1066.0       1567.0
# 4                   LC       64.0       81.0       1930.0       3310.0
# ..                 ...        ...        ...          ...          ...
# 438                 LC       14.0       19.0         26.0         31.5
# 439                 LC       13.0       15.0         13.0         18.0
# 440                 LC       11.5       15.0         11.2         21.4
# 441                 LC       12.0       14.0         13.0         19.0
# 442                 LC       14.0       16.0         25.6         38.4
#
#      MinWingspan  MaxWingspan
# 0           76.0         94.0
# 1           85.0         93.0
# 2          135.0        165.0
# 3          113.0        116.0
# 4          130.0        165.0
# ..           ...          ...
# 438         26.0         29.0
# 439         22.0         22.0
# 440         18.0         23.0
# 441         21.0         23.0
# 442         24.8         26.0
#
# [443 rows x 13 columns]

# %%
birds.dropna(axis='rows', thresh=3)
# Out:
#                              Name          ScientificName  \
# 0    Black-bellied whistling-duck  Dendrocygna autumnalis
# 1          Fulvous whistling-duck     Dendrocygna bicolor
# 2                      Snow goose      Anser caerulescens
# 3                    Ross's goose            Anser rossii
# 4     Greater white-fronted goose         Anser albifrons
# ..                            ...                     ...
# 438                 Blue grosbeak      Passerina caerulea
# 439                Lazuli bunting        Passerina amoena
# 440                Indigo bunting        Passerina cyanea
# 441               Painted bunting         Passerina ciris
# 442                    Dickcissel         Spiza americana
#
#                   Category          Order        Family        Genus  \
# 0    Ducks/Geese/Waterfowl   Anseriformes      Anatidae  Dendrocygna
# 1    Ducks/Geese/Waterfowl   Anseriformes      Anatidae  Dendrocygna
# 2    Ducks/Geese/Waterfowl   Anseriformes      Anatidae        Anser
# 3    Ducks/Geese/Waterfowl   Anseriformes      Anatidae        Anser
# 4    Ducks/Geese/Waterfowl   Anseriformes      Anatidae        Anser
# ..                     ...            ...           ...          ...
# 438       Cardinals/Allies  Passeriformes  Cardinalidae    Passerina
# 439       Cardinals/Allies  Passeriformes  Cardinalidae    Passerina
# 440       Cardinals/Allies  Passeriformes  Cardinalidae    Passerina
# 441       Cardinals/Allies  Passeriformes  Cardinalidae    Passerina
# 442       Cardinals/Allies  Passeriformes  Cardinalidae        Spiza
#
#     ConservationStatus  MinLength  MaxLength  MinBodyMass  MaxBodyMass  \
# 0                   LC       47.0       56.0        652.0       1020.0
# 1                   LC       45.0       53.0        712.0       1050.0
# 2                   LC       64.0       79.0       2050.0       4050.0
# 3                   LC       57.3       64.0       1066.0       1567.0
# 4                   LC       64.0       81.0       1930.0       3310.0
# ..                 ...        ...        ...          ...          ...
# 438                 LC       14.0       19.0         26.0         31.5
# 439                 LC       13.0       15.0         13.0         18.0
# 440                 LC       11.5       15.0         11.2         21.4
# 441                 LC       12.0       14.0         13.0         19.0
# 442                 LC       14.0       16.0         25.6         38.4
#
#      MinWingspan  MaxWingspan
# 0           76.0         94.0
# 1           85.0         93.0
# 2          135.0        165.0
# 3          113.0        116.0
# 4          130.0        165.0
# ..           ...          ...
# 438         26.0         29.0
# 439         22.0         22.0
# 440         18.0         23.0
# 441         21.0         23.0
# 442         24.8         26.0
#
# [443 rows x 13 columns]

# %% [markdown]
# Filling null values

# %%
birds_data_values = birds.iloc[:, 7:14]

# %%
birds_data_values
# Out:
#      MinLength  MaxLength  MinBodyMass  MaxBodyMass  MinWingspan  MaxWingspan
# 0         47.0       56.0        652.0       1020.0         76.0         94.0
# 1         45.0       53.0        712.0       1050.0         85.0         93.0
# 2         64.0       79.0       2050.0       4050.0        135.0        165.0
# 3         57.3       64.0       1066.0       1567.0        113.0        116.0
# 4         64.0       81.0       1930.0       3310.0        130.0        165.0
# ..         ...        ...          ...          ...          ...          ...
# 438       14.0       19.0         26.0         31.5         26.0         29.0
# 439       13.0       15.0         13.0         18.0         22.0         22.0
# 440       11.5       15.0         11.2         21.4         18.0         23.0
# 441       12.0       14.0         13.0         19.0         21.0         23.0
# 442       14.0       16.0         25.6         38.4         24.8         26.0
#
# [443 rows x 6 columns]

# %%
birds_data_values.median()
# Out:
# MinLength      20.5
# MaxLength      25.0
# MinBodyMass    55.0
# MaxBodyMass    89.0
# MinWingspan    38.0
# MaxWingspan    42.0
# dtype: float64

# %%
# The median of the first column is
birds_data_values.fillna(birds_data_values["MinLength"].median(),inplace=True)

# %%
birds_data_values.fillna(0)
# Out:
#      MinLength  MaxLength  MinBodyMass  MaxBodyMass  MinWingspan  MaxWingspan
# 0         47.0       56.0        652.0       1020.0         76.0         94.0
# 1         45.0       53.0        712.0       1050.0         85.0         93.0
# 2         64.0       79.0       2050.0       4050.0        135.0        165.0
# 3         57.3       64.0       1066.0       1567.0        113.0        116.0
# 4         64.0       81.0       1930.0       3310.0        130.0        165.0
# ..         ...        ...          ...          ...          ...          ...
# 438       14.0       19.0         26.0         31.5         26.0         29.0
# 439       13.0       15.0         13.0         18.0         22.0         22.0
# 440       11.5       15.0         11.2         21.4         18.0         23.0
# 441       12.0       14.0         13.0         19.0         21.0         23.0
# 442       14.0       16.0         25.6         38.4         24.8         26.0
#
# [443 rows x 6 columns]

# %%
# What happens if you try to fill null values with a string, like ''?
birds_data_values_filled = birds_data_values.fillna('')
birds_data_values_filled
# Out:
#      MinLength  MaxLength  MinBodyMass  MaxBodyMass  MinWingspan  MaxWingspan
# 0         47.0       56.0        652.0       1020.0         76.0         94.0
# 1         45.0       53.0        712.0       1050.0         85.0         93.0
# 2         64.0       79.0       2050.0       4050.0        135.0        165.0
# 3         57.3       64.0       1066.0       1567.0        113.0        116.0
# 4         64.0       81.0       1930.0       3310.0        130.0        165.0
# ..         ...        ...          ...          ...          ...          ...
# 438       14.0       19.0         26.0         31.5         26.0         29.0
# 439       13.0       15.0         13.0         18.0         22.0         22.0
# 440       11.5       15.0         11.2         21.4         18.0         23.0
# 441       12.0       14.0         13.0         19.0         21.0         23.0
# 442       14.0       16.0         25.6         38.4         24.8         26.0
#
# [443 rows x 6 columns]

# %%
birds_data_values_fill = birds_data_values.fillna(method='ffill')

# %%
birds_data_values.fillna(method='ffill', axis=1)
# Out:
#      MinLength  MaxLength  MinBodyMass  MaxBodyMass  MinWingspan  MaxWingspan
# 0         47.0       56.0        652.0       1020.0         76.0         94.0
# 1         45.0       53.0        712.0       1050.0         85.0         93.0
# 2         64.0       79.0       2050.0       4050.0        135.0        165.0
# 3         57.3       64.0       1066.0       1567.0        113.0        116.0
# 4         64.0       81.0       1930.0       3310.0        130.0        165.0
# ..         ...        ...          ...          ...          ...          ...
# 438       14.0       19.0         26.0         31.5         26.0         29.0
# 439       13.0       15.0         13.0         18.0         22.0         22.0
# 440       11.5       15.0         11.2         21.4         18.0         23.0
# 441       12.0       14.0         13.0         19.0         21.0         23.0
# 442       14.0       16.0         25.6         38.4         24.8         26.0
#
# [443 rows x 6 columns]

# %% [markdown]
# What output does example4.fillna(method='bfill', axis=1) produce?
#
# When you apply the fillna() method to a DataFrame with the method='bfill' parameter and axis=1, it fills the missing values using backward fill along the columns. This means that each missing value is replaced with the next non-null value in the same column, moving from top to bottom.

# %% [markdown]
# What about example4.fillna(method='ffill') or example4.fillna(method='bfill')?
#
# When you apply the fillna() method to a DataFrame with the method='ffill' parameter, it fills the missing values using forward fill. This means that each missing value is replaced with the last non-null value in the same column, moving from top to bottom.
#
# Similarly, when you apply the fillna() method with the method='bfill' parameter, it fills the missing values using backward fill. This means that each missing value is replaced with the next non-null value in the same column, moving from top to bottom.

# %% [markdown]
# Can you think of a longer code snippet to write that can fill all of the null values in example4?
#
# """ for column in df.columns: df[column] = df[column].fillna(0)
#
# """

# %% [markdown]
# Encoding Categorical Data

# %%
# LABEL ENCODING
label = pd.DataFrame([
                      [10,'business class'],
                      [20,'first class'],
                      [30, 'economy class'],
                      [40, 'economy class'],
                      [50, 'economy class'],
                      [60, 'business class']
],columns=['ID','class'])
label
# Out:
#    ID           class
# 0  10  business class
# 1  20     first class
# 2  30   economy class
# 3  40   economy class
# 4  50   economy class
# 5  60  business class

# %%
class_labels = {'business class':0,'economy class':1,'first class':2}
label['class'] = label['class'].replace(class_labels)
label
# Out:
#    ID  class
# 0  10      0
# 1  20      2
# 2  30      1
# 3  40      1
# 4  50      1
# 5  60      0

# %%
# ONE HOT ENCODING
one_hot = pd.DataFrame([
                      [10,'business class'],
                      [20,'first class'],
                      [30, 'economy class'],
                      [40, 'economy class'],
                      [50, 'economy class'],
                      [60, 'business class']
],columns=['ID','class'])

# %%
one_hot_data = pd.get_dummies(one_hot,columns=['class'])

# %%
one_hot_data
# Out:
#    ID  class_business class  class_economy class  class_first class
# 0  10                     1                    0                  0
# 1  20                     0                    0                  1
# 2  30                     0                    1                  0
# 3  40                     0                    1                  0
# 4  50                     0                    1                  0
# 5  60                     1                    0                  0

# %%
# Removing duplicate data
example6 = pd.DataFrame({'letters': ['A','B'] * 2 + ['B'],
                         'numbers': [1, 2, 1, 3, 3]})
example6
# Out:
#   letters  numbers
# 0       A        1
# 1       B        2
# 2       A        1
# 3       B        3
# 4       B        3

# %%
example6.duplicated()
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4     True
# dtype: bool

# %%
# Dropping duplicates: drop_duplicates
example6.drop_duplicates()
# Out:
#   letters  numbers
# 0       A        1
# 1       B        2
# 3       B        3

# %%
example6.drop_duplicates(['letters'])
# Out:
#   letters  numbers
# 0       A        1
# 1       B        2
